# %%
# Numpy 1D Arrays
import numpy as np

a = np.array([1, 2, 3, 4, 5])
print(a)
print(type(a)) # Type
print(a.size) # Size
print(a.ndim) # Dimension
print(a.shape) # Shape

# Indexing and Slicing
print(a[0])
print(a[0:2])
print(a[1:4])

# Basic Operations
u = np.array([5, 0])
v = np.array([1, 1])

z = u + v
print(f"Sume {z}")
print(f"Product {u*v}")

# Other example 
w = [1,0] # or w = np.array([1,0])
v = [1,0] # or v = np.array([1,0])
r = [] 

for n,m in zip(w,v):
    r.append(n+m) # r.append(n*m)
print(r)


# Universal Functions 
b = np.array([1, -2, 3, 4, 5])
max_b= b.max() # return the maximum value - 5

#x = np.array([0, np.pi/2, np.pi])

#y = np.linspace(-2, 2, num=5) # return 5 evenly spaced values from -2 to 2
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(y)
print(y)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
# 5
# 1
# (5,)
# 1
# [1 2]
# [2 3 4]
# Sume [6 1]
# Product [5 0]
# [2, 0]
# [ 0.00000000e+00  6.33814068e-02  1.26254603e-01  1.88123561e-01
#   2.48516095e-01  3.06994523e-01  3.63164884e-01  4.16684376e-01
#   4.67266748e-01  5.14685521e-01  5.58774984e-01  5.99429048e-01
#   6.36598118e-01  6.70284217e-01  7.00534674e-01  7.27434692e-01
#   7.51099165e-01  7.71664077e-01  7.89277825e-01  8.04092770e-01
#   8.16257270e-01  8.25908438e-01  8.33165789e-01  8.38125941e-01
#   8.40858466e-01  8.41402969e-01  8.39767454e-01  8.35927992e-01
#   8.29829711e-01  8.21389071e-01  8.10497413e-01  7.97025693e-01
#   7.80830320e-01  7.61759981e-01  7.39663265e-01  7.14396903e-01
#   6.85834370e-01  6.53874560e-01  6.18450223e-01  5.79535815e-01
#   5.37154416e-01  4.91383362e-01  4.42358280e-01  3.90275253e-01
#   3.35390910e-01  2.78020316e-01  2.18532661e-01  1.57344813e-01
#   9.49129591e-02  3.17226105e-02 -3.17226105e-02 -9.49129591e-02
# ...

# %%
# Exercise 1
import numpy as np
y = np.dot(np.array([1,-1]),np.array([1,1]))
print(type(y))
# Out:
# <class 'numpy.int32'>
